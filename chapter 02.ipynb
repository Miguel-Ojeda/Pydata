# %%
print("Hello World!")
# Out:
# Hello World!

# %%
# %pwd
# Out:
# 'C:\\Users\\Miguel\\Documents\\Repos\\Pydata'

# %%
# !pwd
# Out:
# "pwd" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
pwd
# Out:
# 'C:\\Users\\Miguel\\Documents\\Repos\\Pydata'

# %%
! dir
# Out:
#  El volumen de la unidad C es BOOTCAMP
#  El n£mero de serie del volumen es: 404C-C599
#
#  Directorio de C:\Users\Miguel\Documents\Repos\Pydata
#
# 25/05/2022  20:40    <DIR>          .
# 25/05/2022  20:40    <DIR>          ..
# 25/05/2022  20:32             1.928 .gitignore
# 25/05/2022  20:40    <DIR>          .ipynb_checkpoints
# 25/05/2022  20:40               869 01.ipynb
#                2 archivos          2.797 bytes
#                3 dirs  88.816.201.728 bytes libres

# %%
an_apple = 5
an_orange = 'XL'

# %%
b= [i for i in range(6)]
b
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
import datetime

# %%
b?

# %%
print?

# %%
def add_numbers(a, b):
    """
    Add two numbers together

    Returns
    -------
    the_sum : type of arguments
    """
    return a + b

# %%
add_numbers??

# %%
a = 'foo'

# %%
getattr?

# %%
def isiterable(obj):
    try:
        iter(obj)
        return True
    except TypeError:
        return False

# %%
isiterable([1, 2, 3])
# Out:
# True

# %%
isiterable('abcde')
# Out:
# True

# %%
isiterable(23)
# Out:
# False

# %%
isiterable([1])
# Out:
# True

# %%
isiterable({1, 2, 3})
# Out:
# True

# %%
type({1, 2, 3})
# Out:
# set

# %%
val = 'español'
val_utf8 = val.encode(encoding='utf-8')
val_utf8
# Out:
# b'espa\xc3\xb1ol'

# %%
type(val_utf8)
# Out:
# bytes

# %%
string_val_utf8 = val_utf8.decode(encoding='utf8')
string_val_utf8
# Out:
# 'español'

# %%
val.encode("latin1")
# Out:
# b'espa\xf1ol'

# %%
val.encode('utf-16')
# Out:
# b'\xff\xfee\x00s\x00p\x00a\x00\xf1\x00o\x00l\x00'

# %%
dt = datetime.datetime(2011, 10, 29, 20, 30, 21)
dt
# Out:
# datetime.datetime(2011, 10, 29, 20, 30, 21)

# %%
dt.day, dt.hour, dt.minute, dt.second
# Out:
# (29, 20, 30, 21)

# %%
dt.date()
# Out:
# datetime.date(2011, 10, 29)

# %%
dt.time()
# Out:
# datetime.time(20, 30, 21)

# %%
dt2 = datetime.datetime(2011, 11, 15, 22, 30)

# %%
delta = dt2 - dt
delta
# Out:
# datetime.timedelta(days=17, seconds=7179)

# %%
type(delta)
# Out:
# datetime.timedelta
