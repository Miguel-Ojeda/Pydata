# %%
import pandas as pd
import numpy as np

# %%
# Por comodidad si queremos
from pandas import Series, DataFrame

# %%
serie = Series([4, 7, -5, 3])
# serie = pd.Series(....)
serie
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
serie.array
# Out:
# <PandasArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
serie.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Si queremos un índice concreto, podemos especificarlo
# esto suele dar claridad
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2.array
# Out:
# <PandasArray>
# [4, 7, -5, 3]
# Length: 4, dtype: int64

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2['d']
# Out:
# 4

# %%
obj2[['d', 'a']]
# Out:
# d    4
# a   -5
# dtype: int64

# %%
obj2[ obj2 > 0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
obj2 * 3
# Out:
# d    12
# b    21
# a   -15
# c     9
# dtype: int64

# %%
np.exp(obj2)
# Out:
# d      54.598150
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
'a' in obj2
# Out:
# True

# %%
for elemento in obj2:
    print(elemento)
# Out:
# 4
# 7
# -5
# 3

# %%
obj2['d']
# Out:
# 4

# %%
# Realmente una serie es similar a un diccionario Python... a cada índice le corresponde un value...
# Por tanto, es natural que también podamos crear series desde diccioanrios
sdata = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
obj3 = Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# When you are only passing a dictionary, the index in the resulting Series will respect the order of the keys according to the dictionary's keys method, which depends on the key insertion order.
#
# You can override this by passing an index with the dictionary keys in the order you want them to appear in the resulting Series:

# %%
states = ["California", "Ohio", "Oregon", "Texas"]
obj4 = Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64
